# %% [markdown]
# # Run Caffe
#
# Using the downloaded images and generated categories start Caffe. This is the last stage to start training a model, now we wait while it trains.

# %%
import ansible.runner
import ansible.inventory

instance_ip_address = "174.129.71.20"

hosts = [instance_ip_address]

inventory = ansible.inventory.Inventory(hosts)
ansible_runner = ansible.runner.Runner(
    module_name="shell",
    module_args="./run_all.sh chdir=./scripts executable=/bin/bash async=45 poll=0",
    timeout=20,
    inventory=inventory,
    remote_user="ubuntu"
)

print(ansible_runner.run()["contacted"][instance_ip_address]["stderr"])
# Out:
# ln: failed to create hard link ‘/dev/raw1394’: File exists
# I1010 20:35:48.068704 25032 convert_imageset.cpp:70] Shuffling data
# I1010 20:35:48.407317 25032 convert_imageset.cpp:73] A total of 40 images.
# I1010 20:35:48.407368 25032 convert_imageset.cpp:104] Opening lmdb /home/ubuntu/data/train_lmdb
# E1010 20:35:48.407596 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/IShrgm3f80retx0000000000.jpg
# E1010 20:35:48.407620 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISlaqhir0zskd80000000000.jpg
# E1010 20:35:48.407627 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISppwrvcfch7v80000000000.jpg
# E1010 20:35:48.407644 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/IS1n2w0ufw8wp80000000000.jpg
# E1010 20:35:48.407649 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/IShjufd6b49av80000000000.jpg
# E1010 20:35:48.407655 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISliwzyrwjrv6y0000000000.jpg
# E1010 20:35:48.407660 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISpxiyllc8zbtx0000000000.jpg
# E1010 20:35:48.413537 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/IStoybhy0szs6y0000000000.jpg
# E1010 20:35:48.413558 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/IShbs8s0qqia490000000000.jpg
# E1010 20:35:48.413563 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISxzpzf8kv247y0000000000.jpg
# E1010 20:35:48.413569 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISxfauly3li1ey0000000000.jpg
# E1010 20:35:48.413575 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/IStkz522jgdfey0000000000.jpg
# E1010 20:35:48.413581 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISptbmg203qhxn1000000000.jpg
# E1010 20:35:48.413586 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/IS52t5ji6soney0000000000.jpg
# E1010 20:35:48.413593 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISd4wvha38k4q80000000000.jpg
# E1010 20:35:48.413609 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/IS1r1ik8nolcey0000000000.jpg
# E1010 20:35:48.413615 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISxnwwsdy6z4490000000000.jpg
# E1010 20:35:48.417573 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/IShzeajwuto7290000000000.jpg
# E1010 20:35:48.417593 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/IS56gahf8j6cxn1000000000.jpg
# E1010 20:35:48.422276 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/IStg0kinbo0zp80000000000.jpg
# E1010 20:35:48.422294 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISh366llv427ey0000000000.jpg
# E1010 20:35:48.422300 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISptnnx1gnu67y0000000000.jpg
# E1010 20:35:48.422307 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISxvy3ejjkp4v80000000000.jpg
# E1010 20:35:48.426928 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISdcunglsbjy6y0000000000.jpg
# E1010 20:35:48.430805 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/IS9tcy0qqlga290000000000.jpg
# E1010 20:35:48.430824 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISx3la4sgg79tx0000000000.jpg
# E1010 20:35:48.430830 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISli8thnc4tg5x0000000000.jpg
# E1010 20:35:48.430835 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/IShn9ayvvuhkxn1000000000.jpg
# E1010 20:35:48.430847 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISdcimzlcre9xn1000000000.jpg
# E1010 20:35:48.430853 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISxzdyy84byexn1000000000.jpg
# E1010 20:35:48.430858 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISd8vh1pa0xkey0000000000.jpg
# E1010 20:35:48.430869 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/IS95qw9uliad490000000000.jpg
# E1010 20:35:48.430874 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/ISphuka7uyq7490000000000.jpg
# E1010 20:35:48.434876 25032 io.cpp:77] Could not open or find file /home/ubuntu/images/IS56sbyeo3b17y0000000000.jpg
# E1010 20:35:48.445556 25032 convert_imageset.cpp:193] Processed 6 files.
# I1010 20:35:48.531620 25035 convert_imageset.cpp:70] Shuffling data
# I1010 20:35:48.870820 25035 convert_imageset.cpp:73] A total of 10 images.
# I1010 20:35:48.870877 25035 convert_imageset.cpp:104] Opening lmdb /home/ubuntu/data/val_lmdb
# E1010 20:35:48.871114 25035 io.cpp:77] Could not open or find file /home/ubuntu/images/IS521gwpnsx1v80000000000.jpg
# E1010 20:35:48.871137 25035 io.cpp:77] Could not open or find file /home/ubuntu/images/ISp98i3szca4ey0000000000.jpg
# E1010 20:35:48.871145 25035 io.cpp:77] Could not open or find file /home/ubuntu/images/ISlextjve85iey0000000000.jpg
# E1010 20:35:48.871150 25035 io.cpp:77] Could not open or find file /home/ubuntu/images/IS9x3u2frwt9ey0000000000.jpg
# E1010 20:35:48.871158 25035 io.cpp:77] Could not open or find file /home/ubuntu/images/IS52x8kofvqr0x0000000000.jpg
# E1010 20:35:48.877054 25035 io.cpp:77] Could not open or find file /home/ubuntu/images/ISp5hm13z1x4290000000000.jpg
# E1010 20:35:48.877074 25035 io.cpp:77] Could not open or find file /home/ubuntu/images/IStshtyb55k4zl1000000000.jpg
# E1010 20:35:48.877081 25035 io.cpp:77] Could not open or find file /home/ubuntu/images/ISlay70h7gs1q80000000000.jpg
# E1010 20:35:48.887359 25035 convert_imageset.cpp:193] Processed 2 files.
# E1010 20:35:48.978240 25038 compute_image_mean.cpp:149] Processed 6 files.
# ./train.sh: 7: ./train.sh: disown: not found
# I1010 20:35:49.844954 25041 caffe.cpp:99] Use GPU with device ID 0
# I1010 20:35:50.185689 25041 caffe.cpp:107] Starting Optimization
# I1010 20:35:50.185818 25041 solver.cpp:32] Initializing solver from parameters:
# test_iter: 1000
# test_interval: 1000
# base_lr: 0.01
# display: 20
# max_iter: 450000
# lr_policy: "step"
# gamma: 0.1
# momentum: 0.9
# weight_decay: 0.0005
# stepsize: 100000
# snapshot: 10000
# snapshot_prefix: "../snapshots/train"
# solver_mode: GPU
# net: "../prototxt/train_val.prototxt"
# I1010 20:35:50.185858 25041 solver.cpp:67] Creating training net from net file: ../prototxt/train_val.prototxt
# I1010 20:35:50.186417 25041 net.cpp:275] The NetState phase (0) differed from the phase (1) specified by a rule in layer data
# I1010 20:35:50.186450 25041 net.cpp:275] The NetState phase (0) differed from the phase (1) specified by a rule in layer accuracy
# I1010 20:35:50.186625 25041 net.cpp:39] Initializing net from parameters:
# name: "CaffeNet"
# layers {
#   top: "data"
#   top: "label"
#   name: "data"
#   type: DATA
#   data_param {
#     source: "../data/train_lmdb"
#     batch_size: 256
#     backend: LMDB
#   }
#   include {
#     phase: TRAIN
#   }
#   transform_param {
#     mirror: true
#     crop_size: 227
#     mean_file: "../data/mean.binaryproto"
#   }
# }
# layers {
#   bottom: "data"
#   top: "conv1"
#   name: "conv1"
#   type: CONVOLUTION
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "conv1"
#   top: "conv1"
#   name: "relu1"
#   type: RELU
# }
# layers {
#   bottom: "conv1"
#   top: "pool1"
#   name: "pool1"
#   type: POOLING
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layers {
#   bottom: "pool1"
#   top: "norm1"
#   name: "norm1"
#   type: LRN
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layers {
#   bottom: "norm1"
#   top: "conv2"
#   name: "conv2"
#   type: CONVOLUTION
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 1
#     }
#   }
# }
# layers {
#   bottom: "conv2"
#   top: "conv2"
#   name: "relu2"
#   type: RELU
# }
# layers {
#   bottom: "conv2"
#   top: "pool2"
#   name: "pool2"
#   type: POOLING
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layers {
#   bottom: "pool2"
#   top: "norm2"
#   name: "norm2"
#   type: LRN
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layers {
#   bottom: "norm2"
#   top: "conv3"
#   name: "conv3"
#   type: CONVOLUTION
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "conv3"
#   top: "conv3"
#   name: "relu3"
#   type: RELU
# }
# layers {
#   bottom: "conv3"
#   top: "conv4"
#   name: "conv4"
#   type: CONVOLUTION
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 1
#     }
#   }
# }
# layers {
#   bottom: "conv4"
#   top: "conv4"
#   name: "relu4"
#   type: RELU
# }
# layers {
#   bottom: "conv4"
#   top: "conv5"
#   name: "conv5"
#   type: CONVOLUTION
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 1
#     }
#   }
# }
# layers {
#   bottom: "conv5"
#   top: "conv5"
#   name: "relu5"
#   type: RELU
# }
# layers {
#   bottom: "conv5"
#   top: "pool5"
#   name: "pool5"
#   type: POOLING
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layers {
#   bottom: "pool5"
#   top: "fc6"
#   name: "fc6"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 1
#     }
#   }
# }
# layers {
#   bottom: "fc6"
#   top: "fc6"
#   name: "relu6"
#   type: RELU
# }
# layers {
#   bottom: "fc6"
#   top: "fc6"
#   name: "drop6"
#   type: DROPOUT
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layers {
#   bottom: "fc6"
#   top: "fc7"
#   name: "fc7"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 1
#     }
#   }
# }
# layers {
#   bottom: "fc7"
#   top: "fc7"
#   name: "relu7"
#   type: RELU
# }
# layers {
#   bottom: "fc7"
#   top: "fc7"
#   name: "drop7"
#   type: DROPOUT
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layers {
#   bottom: "fc7"
#   top: "fc8"
#   name: "fc8"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 1000
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc8"
#   bottom: "label"
#   top: "loss"
#   name: "loss"
#   type: SOFTMAX_LOSS
# }
# state {
#   phase: TRAIN
# }
# I1010 20:35:50.186771 25041 net.cpp:67] Creating Layer data
# I1010 20:35:50.186790 25041 net.cpp:356] data -> data
# I1010 20:35:50.186811 25041 net.cpp:356] data -> label
# I1010 20:35:50.186832 25041 net.cpp:96] Setting up data
# I1010 20:35:50.186923 25041 data_layer.cpp:68] Opening lmdb ../data/train_lmdb
# I1010 20:35:50.187098 25041 data_layer.cpp:128] output data size: 256,3,227,227
# I1010 20:35:50.187114 25041 base_data_layer.cpp:36] Loading mean file from../data/mean.binaryproto
# I1010 20:35:50.228116 25041 net.cpp:103] Top shape: 256 3 227 227 (39574272)
# I1010 20:35:50.228158 25041 net.cpp:103] Top shape: 256 1 1 1 (256)
# I1010 20:35:50.228198 25041 net.cpp:67] Creating Layer conv1
# I1010 20:35:50.228204 25041 net.cpp:394] conv1 <- data
# I1010 20:35:50.228225 25041 net.cpp:356] conv1 -> conv1
# I1010 20:35:50.228241 25041 net.cpp:96] Setting up conv1
# I1010 20:35:50.250782 25041 net.cpp:103] Top shape: 256 96 55 55 (74342400)
# I1010 20:35:50.250862 25041 net.cpp:67] Creating Layer relu1
# I1010 20:35:50.250871 25041 net.cpp:394] relu1 <- conv1
# I1010 20:35:50.250879 25041 net.cpp:345] relu1 -> conv1 (in-place)
# I1010 20:35:50.250888 25041 net.cpp:96] Setting up relu1
# I1010 20:35:50.250901 25041 net.cpp:103] Top shape: 256 96 55 55 (74342400)
# I1010 20:35:50.250917 25041 net.cpp:67] Creating Layer pool1
# I1010 20:35:50.250921 25041 net.cpp:394] pool1 <- conv1
# I1010 20:35:50.250927 25041 net.cpp:356] pool1 -> pool1
# I1010 20:35:50.250934 25041 net.cpp:96] Setting up pool1
# I1010 20:35:50.250957 25041 net.cpp:103] Top shape: 256 96 27 27 (17915904)
# I1010 20:35:50.250972 25041 net.cpp:67] Creating Layer norm1
# I1010 20:35:50.250975 25041 net.cpp:394] norm1 <- pool1
# I1010 20:35:50.250982 25041 net.cpp:356] norm1 -> norm1
# I1010 20:35:50.250991 25041 net.cpp:96] Setting up norm1
# I1010 20:35:50.250999 25041 net.cpp:103] Top shape: 256 96 27 27 (17915904)
# I1010 20:35:50.251018 25041 net.cpp:67] Creating Layer conv2
# I1010 20:35:50.251021 25041 net.cpp:394] conv2 <- norm1
# I1010 20:35:50.251027 25041 net.cpp:356] conv2 -> conv2
# I1010 20:35:50.251035 25041 net.cpp:96] Setting up conv2
# I1010 20:35:50.261523 25041 net.cpp:103] Top shape: 256 256 27 27 (47775744)
# I1010 20:35:50.261554 25041 net.cpp:67] Creating Layer relu2
# I1010 20:35:50.261559 25041 net.cpp:394] relu2 <- conv2
# I1010 20:35:50.261567 25041 net.cpp:345] relu2 -> conv2 (in-place)
# I1010 20:35:50.261575 25041 net.cpp:96] Setting up relu2
# I1010 20:35:50.261582 25041 net.cpp:103] Top shape: 256 256 27 27 (47775744)
# I1010 20:35:50.261590 25041 net.cpp:67] Creating Layer pool2
# I1010 20:35:50.261592 25041 net.cpp:394] pool2 <- conv2
# I1010 20:35:50.261598 25041 net.cpp:356] pool2 -> pool2
# I1010 20:35:50.261603 25041 net.cpp:96] Setting up pool2
# I1010 20:35:50.261613 25041 net.cpp:103] Top shape: 256 256 13 13 (11075584)
# I1010 20:35:50.261662 25041 net.cpp:67] Creating Layer norm2
# I1010 20:35:50.261667 25041 net.cpp:394] norm2 <- pool2
# I1010 20:35:50.261673 25041 net.cpp:356] norm2 -> norm2
# I1010 20:35:50.261679 25041 net.cpp:96] Setting up norm2
# I1010 20:35:50.261683 25041 net.cpp:103] Top shape: 256 256 13 13 (11075584)
# I1010 20:35:50.261693 25041 net.cpp:67] Creating Layer conv3
# I1010 20:35:50.261704 25041 net.cpp:394] conv3 <- norm2
# I1010 20:35:50.261710 25041 net.cpp:356] conv3 -> conv3
# I1010 20:35:50.261718 25041 net.cpp:96] Setting up conv3
# I1010 20:35:50.291425 25041 net.cpp:103] Top shape: 256 384 13 13 (16613376)
# I1010 20:35:50.291481 25041 net.cpp:67] Creating Layer relu3
# I1010 20:35:50.291487 25041 net.cpp:394] relu3 <- conv3
# I1010 20:35:50.291497 25041 net.cpp:345] relu3 -> conv3 (in-place)
# I1010 20:35:50.291506 25041 net.cpp:96] Setting up relu3
# I1010 20:35:50.291513 25041 net.cpp:103] Top shape: 256 384 13 13 (16613376)
# I1010 20:35:50.291522 25041 net.cpp:67] Creating Layer conv4
# I1010 20:35:50.291527 25041 net.cpp:394] conv4 <- conv3
# I1010 20:35:50.291532 25041 net.cpp:356] conv4 -> conv4
# I1010 20:35:50.291538 25041 net.cpp:96] Setting up conv4
# I1010 20:35:50.314189 25041 net.cpp:103] Top shape: 256 384 13 13 (16613376)
# I1010 20:35:50.314249 25041 net.cpp:67] Creating Layer relu4
# I1010 20:35:50.314256 25041 net.cpp:394] relu4 <- conv4
# I1010 20:35:50.314265 25041 net.cpp:345] relu4 -> conv4 (in-place)
# I1010 20:35:50.314273 25041 net.cpp:96] Setting up relu4
# I1010 20:35:50.314281 25041 net.cpp:103] Top shape: 256 384 13 13 (16613376)
# I1010 20:35:50.314291 25041 net.cpp:67] Creating Layer conv5
# I1010 20:35:50.314293 25041 net.cpp:394] conv5 <- conv4
# I1010 20:35:50.314301 25041 net.cpp:356] conv5 -> conv5
# I1010 20:35:50.314308 25041 net.cpp:96] Setting up conv5
# I1010 20:35:50.329416 25041 net.cpp:103] Top shape: 256 256 13 13 (11075584)
# I1010 20:35:50.329463 25041 net.cpp:67] Creating Layer relu5
# I1010 20:35:50.329469 25041 net.cpp:394] relu5 <- conv5
# I1010 20:35:50.329476 25041 net.cpp:345] relu5 -> conv5 (in-place)
# I1010 20:35:50.329484 25041 net.cpp:96] Setting up relu5
# I1010 20:35:50.329493 25041 net.cpp:103] Top shape: 256 256 13 13 (11075584)
# I1010 20:35:50.329504 25041 net.cpp:67] Creating Layer pool5
# I1010 20:35:50.329509 25041 net.cpp:394] pool5 <- conv5
# I1010 20:35:50.329514 25041 net.cpp:356] pool5 -> pool5
# I1010 20:35:50.329530 25041 net.cpp:96] Setting up pool5
# I1010 20:35:50.329540 25041 net.cpp:103] Top shape: 256 256 6 6 (2359296)
# I1010 20:35:50.329553 25041 net.cpp:67] Creating Layer fc6
# I1010 20:35:50.329557 25041 net.cpp:394] fc6 <- pool5
# I1010 20:35:50.329563 25041 net.cpp:356] fc6 -> fc6
# I1010 20:35:50.329571 25041 net.cpp:96] Setting up fc6
