# %% [markdown]
# # Run Caffe
#
# Using the downloaded images and generated categories start Caffe. This is the last stage to start training a model, now we wait while it trains.

# %%
import ansible.runner
import ansible.inventory

instance_ip_address = "174.129.71.20"

hosts = [instance_ip_address]

inventory = ansible.inventory.Inventory(hosts)
ansible_runner = ansible.runner.Runner(
    module_name="shell",
    module_args="./run_all.sh chdir=./scripts executable=/bin/bash",
    timeout=10,
    inventory=inventory,
    remote_user="ubuntu"
)

print(ansible_runner.run()["contacted"][instance_ip_address]["stderr"])
# Out:
# ln: failed to create hard link ‘/dev/raw1394’: File exists
# I1010 18:07:27.124752 14061 convert_imageset.cpp:70] Shuffling data
# I1010 18:07:27.907909 14061 convert_imageset.cpp:73] A total of 40 images.
# I1010 18:07:27.907973 14061 convert_imageset.cpp:104] Opening lmdb /home/ubuntu/data/train_lmdb
# E1010 18:07:27.908220 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/IS56gahf8j6cxn1000000000.jpg
# E1010 18:07:27.908247 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/IS95qw9uliad490000000000.jpg
# E1010 18:07:27.914095 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISx3la4sgg79tx0000000000.jpg
# E1010 18:07:27.914120 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/IShbs8s0qqia490000000000.jpg
# E1010 18:07:27.914132 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/IS56sbyeo3b17y0000000000.jpg
# E1010 18:07:27.914142 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISdcimzlcre9xn1000000000.jpg
# E1010 18:07:27.914154 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISppwrvcfch7v80000000000.jpg
# E1010 18:07:27.918018 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISh366llv427ey0000000000.jpg
# E1010 18:07:27.918042 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISlextjve85iey0000000000.jpg
# E1010 18:07:27.918054 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/IStkz522jgdfey0000000000.jpg
# E1010 18:07:27.918066 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISxfauly3li1ey0000000000.jpg
# E1010 18:07:27.918076 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISlay70h7gs1q80000000000.jpg
# E1010 18:07:27.922281 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/IShn9ayvvuhkxn1000000000.jpg
# E1010 18:07:27.922304 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISxzdyy84byexn1000000000.jpg
# E1010 18:07:27.922317 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/IShjufd6b49av80000000000.jpg
# E1010 18:07:27.922328 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/IStshtyb55k4zl1000000000.jpg
# E1010 18:07:27.922339 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISp5hm13z1x4290000000000.jpg
# E1010 18:07:27.926987 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/IStoybhy0szs6y0000000000.jpg
# E1010 18:07:27.927011 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISd4wvha38k4q80000000000.jpg
# E1010 18:07:27.927022 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/IStg0kinbo0zp80000000000.jpg
# E1010 18:07:27.927033 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/IS521gwpnsx1v80000000000.jpg
# E1010 18:07:27.930949 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/IS9x3u2frwt9ey0000000000.jpg
# E1010 18:07:27.930971 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISlaqhir0zskd80000000000.jpg
# E1010 18:07:27.930984 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISphuka7uyq7490000000000.jpg
# E1010 18:07:27.930994 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISptbmg203qhxn1000000000.jpg
# E1010 18:07:27.931005 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISp98i3szca4ey0000000000.jpg
# E1010 18:07:27.931025 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISd8vh1pa0xkey0000000000.jpg
# E1010 18:07:27.931035 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/IS9tcy0qqlga290000000000.jpg
# E1010 18:07:27.934798 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISxzpzf8kv247y0000000000.jpg
# E1010 18:07:27.934819 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISptnnx1gnu67y0000000000.jpg
# E1010 18:07:27.934831 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISliwzyrwjrv6y0000000000.jpg
# E1010 18:07:27.934842 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISxvy3ejjkp4v80000000000.jpg
# E1010 18:07:27.934854 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/IShrgm3f80retx0000000000.jpg
# E1010 18:07:27.934872 14061 io.cpp:77] Could not open or find file /home/ubuntu/images/ISdcunglsbjy6y0000000000.jpg
# E1010 18:07:27.945380 14061 convert_imageset.cpp:193] Processed 6 files.
# I1010 18:07:27.983814 14068 convert_imageset.cpp:70] Shuffling data
# I1010 18:07:28.762466 14068 convert_imageset.cpp:73] A total of 10 images.
# I1010 18:07:28.762526 14068 convert_imageset.cpp:104] Opening lmdb /home/ubuntu/data/val_lmdb
# E1010 18:07:28.762768 14068 io.cpp:77] Could not open or find file /home/ubuntu/images/ISli8thnc4tg5x0000000000.jpg
# E1010 18:07:28.762791 14068 io.cpp:77] Could not open or find file /home/ubuntu/images/IShzeajwuto7290000000000.jpg
# E1010 18:07:28.762797 14068 io.cpp:77] Could not open or find file /home/ubuntu/images/IS52x8kofvqr0x0000000000.jpg
# E1010 18:07:28.762804 14068 io.cpp:77] Could not open or find file /home/ubuntu/images/ISxnwwsdy6z4490000000000.jpg
# E1010 18:07:28.762809 14068 io.cpp:77] Could not open or find file /home/ubuntu/images/IS1n2w0ufw8wp80000000000.jpg
# E1010 18:07:28.769218 14068 io.cpp:77] Could not open or find file /home/ubuntu/images/ISpxiyllc8zbtx0000000000.jpg
# E1010 18:07:28.773092 14068 io.cpp:77] Could not open or find file /home/ubuntu/images/IS52t5ji6soney0000000000.jpg
# E1010 18:07:28.773111 14068 io.cpp:77] Could not open or find file /home/ubuntu/images/IS1r1ik8nolcey0000000000.jpg
# E1010 18:07:28.779145 14068 convert_imageset.cpp:193] Processed 2 files.
# E1010 18:07:28.822849 14077 compute_image_mean.cpp:149] Processed 6 files.
# I1010 18:07:29.704855 14086 caffe.cpp:99] Use GPU with device ID 0
# I1010 18:07:30.442193 14086 caffe.cpp:107] Starting Optimization
# I1010 18:07:30.442330 14086 solver.cpp:32] Initializing solver from parameters:
# test_iter: 1000
# test_interval: 1000
# base_lr: 0.01
# display: 20
# max_iter: 450000
# lr_policy: "step"
# gamma: 0.1
# momentum: 0.9
# weight_decay: 0.0005
# stepsize: 100000
# snapshot: 10000
# snapshot_prefix: "../snapshots/train"
# solver_mode: GPU
# net: "../prototxt/train_val.prototxt"
# I1010 18:07:30.442378 14086 solver.cpp:67] Creating training net from net file: ../prototxt/train_val.prototxt
# I1010 18:07:30.442962 14086 net.cpp:275] The NetState phase (0) differed from the phase (1) specified by a rule in layer data
# I1010 18:07:30.443007 14086 net.cpp:275] The NetState phase (0) differed from the phase (1) specified by a rule in layer accuracy
# I1010 18:07:30.443218 14086 net.cpp:39] Initializing net from parameters:
# name: "CaffeNet"
# layers {
#   top: "data"
#   top: "label"
#   name: "data"
#   type: DATA
#   data_param {
#     source: "../data/train_lmdb"
#     batch_size: 256
#     backend: LMDB
#   }
#   include {
#     phase: TRAIN
#   }
#   transform_param {
#     mirror: true
#     crop_size: 227
#     mean_file: "../data/mean.binaryproto"
#   }
# }
# layers {
#   bottom: "data"
#   top: "conv1"
#   name: "conv1"
#   type: CONVOLUTION
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   convolution_param {
#     num_output: 96
#     kernel_size: 11
#     stride: 4
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "conv1"
#   top: "conv1"
#   name: "relu1"
#   type: RELU
# }
# layers {
#   bottom: "conv1"
#   top: "pool1"
#   name: "pool1"
#   type: POOLING
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layers {
#   bottom: "pool1"
#   top: "norm1"
#   name: "norm1"
#   type: LRN
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layers {
#   bottom: "norm1"
#   top: "conv2"
#   name: "conv2"
#   type: CONVOLUTION
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   convolution_param {
#     num_output: 256
#     pad: 2
#     kernel_size: 5
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 1
#     }
#   }
# }
# layers {
#   bottom: "conv2"
#   top: "conv2"
#   name: "relu2"
#   type: RELU
# }
# layers {
#   bottom: "conv2"
#   top: "pool2"
#   name: "pool2"
#   type: POOLING
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layers {
#   bottom: "pool2"
#   top: "norm2"
#   name: "norm2"
#   type: LRN
#   lrn_param {
#     local_size: 5
#     alpha: 0.0001
#     beta: 0.75
#   }
# }
# layers {
#   bottom: "norm2"
#   top: "conv3"
#   name: "conv3"
#   type: CONVOLUTION
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "conv3"
#   top: "conv3"
#   name: "relu3"
#   type: RELU
# }
# layers {
#   bottom: "conv3"
#   top: "conv4"
#   name: "conv4"
#   type: CONVOLUTION
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   convolution_param {
#     num_output: 384
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 1
#     }
#   }
# }
# layers {
#   bottom: "conv4"
#   top: "conv4"
#   name: "relu4"
#   type: RELU
# }
# layers {
#   bottom: "conv4"
#   top: "conv5"
#   name: "conv5"
#   type: CONVOLUTION
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     group: 2
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 1
#     }
#   }
# }
# layers {
#   bottom: "conv5"
#   top: "conv5"
#   name: "relu5"
#   type: RELU
# }
# layers {
#   bottom: "conv5"
#   top: "pool5"
#   name: "pool5"
#   type: POOLING
#   pooling_param {
#     pool: MAX
#     kernel_size: 3
#     stride: 2
#   }
# }
# layers {
#   bottom: "pool5"
#   top: "fc6"
#   name: "fc6"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 1
#     }
#   }
# }
# layers {
#   bottom: "fc6"
#   top: "fc6"
#   name: "relu6"
#   type: RELU
# }
# layers {
#   bottom: "fc6"
#   top: "fc6"
#   name: "drop6"
#   type: DROPOUT
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layers {
#   bottom: "fc6"
#   top: "fc7"
#   name: "fc7"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 4096
#     weight_filler {
#       type: "gaussian"
#       std: 0.005
#     }
#     bias_filler {
#       type: "constant"
#       value: 1
#     }
#   }
# }
# layers {
#   bottom: "fc7"
#   top: "fc7"
#   name: "relu7"
#   type: RELU
# }
# layers {
#   bottom: "fc7"
#   top: "fc7"
#   name: "drop7"
#   type: DROPOUT
#   dropout_param {
#     dropout_ratio: 0.5
#   }
# }
# layers {
#   bottom: "fc7"
#   top: "fc8"
#   name: "fc8"
#   type: INNER_PRODUCT
#   blobs_lr: 1
#   blobs_lr: 2
#   weight_decay: 1
#   weight_decay: 0
#   inner_product_param {
#     num_output: 1000
#     weight_filler {
#       type: "gaussian"
#       std: 0.01
#     }
#     bias_filler {
#       type: "constant"
#       value: 0
#     }
#   }
# }
# layers {
#   bottom: "fc8"
#   bottom: "label"
#   top: "loss"
#   name: "loss"
#   type: SOFTMAX_LOSS
# }
# state {
#   phase: TRAIN
# }
# I1010 18:07:30.443385 14086 net.cpp:67] Creating Layer data
# I1010 18:07:30.443408 14086 net.cpp:356] data -> data
# I1010 18:07:30.443439 14086 net.cpp:356] data -> label
# I1010 18:07:30.443472 14086 net.cpp:96] Setting up data
# I1010 18:07:30.443583 14086 data_layer.cpp:68] Opening lmdb ../data/train_lmdb
# I1010 18:07:30.443771 14086 data_layer.cpp:128] output data size: 256,3,227,227
# I1010 18:07:30.443794 14086 base_data_layer.cpp:36] Loading mean file from../data/mean.binaryproto
# I1010 18:07:30.484971 14086 net.cpp:103] Top shape: 256 3 227 227 (39574272)
# I1010 18:07:30.485013 14086 net.cpp:103] Top shape: 256 1 1 1 (256)
# I1010 18:07:30.485069 14086 net.cpp:67] Creating Layer conv1
# I1010 18:07:30.485092 14086 net.cpp:394] conv1 <- data
# I1010 18:07:30.485124 14086 net.cpp:356] conv1 -> conv1
# I1010 18:07:30.485154 14086 net.cpp:96] Setting up conv1
# I1010 18:07:30.592808 14086 net.cpp:103] Top shape: 256 96 55 55 (74342400)
# I1010 18:07:30.592890 14086 net.cpp:67] Creating Layer relu1
# I1010 18:07:30.592902 14086 net.cpp:394] relu1 <- conv1
# I1010 18:07:30.592916 14086 net.cpp:345] relu1 -> conv1 (in-place)
# I1010 18:07:30.592939 14086 net.cpp:96] Setting up relu1
# I1010 18:07:30.592960 14086 net.cpp:103] Top shape: 256 96 55 55 (74342400)
# I1010 18:07:30.592983 14086 net.cpp:67] Creating Layer pool1
# I1010 18:07:30.592991 14086 net.cpp:394] pool1 <- conv1
# I1010 18:07:30.593006 14086 net.cpp:356] pool1 -> pool1
# I1010 18:07:30.593021 14086 net.cpp:96] Setting up pool1
# I1010 18:07:30.593056 14086 net.cpp:103] Top shape: 256 96 27 27 (17915904)
# I1010 18:07:30.593077 14086 net.cpp:67] Creating Layer norm1
# I1010 18:07:30.593086 14086 net.cpp:394] norm1 <- pool1
# I1010 18:07:30.593097 14086 net.cpp:356] norm1 -> norm1
# I1010 18:07:30.593122 14086 net.cpp:96] Setting up norm1
# I1010 18:07:30.593137 14086 net.cpp:103] Top shape: 256 96 27 27 (17915904)
# I1010 18:07:30.593154 14086 net.cpp:67] Creating Layer conv2
# I1010 18:07:30.593165 14086 net.cpp:394] conv2 <- norm1
# I1010 18:07:30.593178 14086 net.cpp:356] conv2 -> conv2
# I1010 18:07:30.593200 14086 net.cpp:96] Setting up conv2
# I1010 18:07:30.603440 14086 net.cpp:103] Top shape: 256 256 27 27 (47775744)
# I1010 18:07:30.603474 14086 net.cpp:67] Creating Layer relu2
# I1010 18:07:30.603484 14086 net.cpp:394] relu2 <- conv2
# I1010 18:07:30.603494 14086 net.cpp:345] relu2 -> conv2 (in-place)
# I1010 18:07:30.603518 14086 net.cpp:96] Setting up relu2
# I1010 18:07:30.603531 14086 net.cpp:103] Top shape: 256 256 27 27 (47775744)
# I1010 18:07:30.603546 14086 net.cpp:67] Creating Layer pool2
# I1010 18:07:30.603554 14086 net.cpp:394] pool2 <- conv2
# I1010 18:07:30.603569 14086 net.cpp:356] pool2 -> pool2
# I1010 18:07:30.603590 14086 net.cpp:96] Setting up pool2
# I1010 18:07:30.603605 14086 net.cpp:103] Top shape: 256 256 13 13 (11075584)
# I1010 18:07:30.603662 14086 net.cpp:67] Creating Layer norm2
# I1010 18:07:30.603672 14086 net.cpp:394] norm2 <- pool2
# I1010 18:07:30.603683 14086 net.cpp:356] norm2 -> norm2
# I1010 18:07:30.603703 14086 net.cpp:96] Setting up norm2
# I1010 18:07:30.603713 14086 net.cpp:103] Top shape: 256 256 13 13 (11075584)
# I1010 18:07:30.603732 14086 net.cpp:67] Creating Layer conv3
# I1010 18:07:30.603741 14086 net.cpp:394] conv3 <- norm2
# I1010 18:07:30.603757 14086 net.cpp:356] conv3 -> conv3
# I1010 18:07:30.603778 14086 net.cpp:96] Setting up conv3
# I1010 18:07:30.632714 14086 net.cpp:103] Top shape: 256 384 13 13 (16613376)
# I1010 18:07:30.632777 14086 net.cpp:67] Creating Layer relu3
# I1010 18:07:30.632788 14086 net.cpp:394] relu3 <- conv3
# I1010 18:07:30.632799 14086 net.cpp:345] relu3 -> conv3 (in-place)
# I1010 18:07:30.632812 14086 net.cpp:96] Setting up relu3
# I1010 18:07:30.632836 14086 net.cpp:103] Top shape: 256 384 13 13 (16613376)
# I1010 18:07:30.632859 14086 net.cpp:67] Creating Layer conv4
# I1010 18:07:30.632869 14086 net.cpp:394] conv4 <- conv3
# I1010 18:07:30.632885 14086 net.cpp:356] conv4 -> conv4
# I1010 18:07:30.632901 14086 net.cpp:96] Setting up conv4
# I1010 18:07:30.654923 14086 net.cpp:103] Top shape: 256 384 13 13 (16613376)
# I1010 18:07:30.654958 14086 net.cpp:67] Creating Layer relu4
# I1010 18:07:30.654968 14086 net.cpp:394] relu4 <- conv4
# I1010 18:07:30.654978 14086 net.cpp:345] relu4 -> conv4 (in-place)
# I1010 18:07:30.654989 14086 net.cpp:96] Setting up relu4
# I1010 18:07:30.655005 14086 net.cpp:103] Top shape: 256 384 13 13 (16613376)
# I1010 18:07:30.655026 14086 net.cpp:67] Creating Layer conv5
# I1010 18:07:30.655036 14086 net.cpp:394] conv5 <- conv4
# I1010 18:07:30.655048 14086 net.cpp:356] conv5 -> conv5
# I1010 18:07:30.655063 14086 net.cpp:96] Setting up conv5
# I1010 18:07:30.669709 14086 net.cpp:103] Top shape: 256 256 13 13 (11075584)
# I1010 18:07:30.669744 14086 net.cpp:67] Creating Layer relu5
# I1010 18:07:30.669754 14086 net.cpp:394] relu5 <- conv5
# I1010 18:07:30.669764 14086 net.cpp:345] relu5 -> conv5 (in-place)
# I1010 18:07:30.669780 14086 net.cpp:96] Setting up relu5
# I1010 18:07:30.669792 14086 net.cpp:103] Top shape: 256 256 13 13 (11075584)
# I1010 18:07:30.669808 14086 net.cpp:67] Creating Layer pool5
# I1010 18:07:30.669826 14086 net.cpp:394] pool5 <- conv5
# I1010 18:07:30.669839 14086 net.cpp:356] pool5 -> pool5
# I1010 18:07:30.669854 14086 net.cpp:96] Setting up pool5
# I1010 18:07:30.669872 14086 net.cpp:103] Top shape: 256 256 6 6 (2359296)
# I1010 18:07:30.669901 14086 net.cpp:67] Creating Layer fc6
# I1010 18:07:30.669913 14086 net.cpp:394] fc6 <- pool5
# I1010 18:07:30.669924 14086 net.cpp:356] fc6 -> fc6
# I1010 18:07:30.669940 14086 net.cpp:96] Setting up fc6
