# %% [markdown]
# # Download Zillow Images
#
# While writing this, Zillow's API was down so instead I used a URL on their website which doesn't seem to use the API.
#
# **NOTE** I do not recommend using this method for getting results from Zillow.com and would say their API is a better route.

# %%
from collections import namedtuple
from time import sleep
from lxml import html

import requests
import logging
import json

# %%
# Constants used in getting results from the API.
Result = namedtuple("Result", ["guid", "image_url", "price"])

# Region for Portland, OR according to Zillow.com.
PORTLAND = "-123014946,45489020,-122293968,45594822"

logger = logging.getLogger("Download Zillow Images")
logger.setLevel(logging.DEBUG)

# %%
def get_images_from_detail_zillow_listing(zp_id):
    """
    Open a Zillow detail page and scrape it for any photo URLs.
    
    Parameters
    ----------
    zp_id : str
        Zillow listing ID.
        
    Returns
    -------
    list(str)
        List of all the images found on the page.
        
    Notes
    -----
    Will return None if an error occurs.
    """
    response = requests.get(
        "http://www.zillow.com/homedetails/{zp_id}_zpid/".format(
            zp_id=zp_id))

    if response.status_code is not 200:
        logger.error("Trouble hitting zillow.com: %i", response.status_code)
        return None

    tree = html.fromstring(response.text)

    return map(
        lambda i: i.get("src") or i.get("href"),
        tree.xpath("//ol[@class='photos']/li/a/img")
    )


def get_page_of_zillow_articles(page, rect=PORTLAND):
    """
    Request a page of search results from Zillow's "GetResults.html" webpage.
    
    Parameters
    ----------
    page : int
        Page number to request, can be used in pagination.
    rect : csv
        Latitude and longitude coordinates for the map.
        
    Returns
    -------
    list
        List of Articles found in the search which include their Price and preview image URLs.
    """
    url = 'http://www.zillow.com/search/GetResults.htm'

    response = requests.get(
        url,
        params={
            "spt": "homes",  # We ignore any forclosure or renting properties
            "status": 100000,
            "zoom": 10,
            "rect": rect,
            "sort": "days",
            "search": "maplist",
            "zoom": 10,
            "p": page,
        })

    if response.status_code is not 200:
        logger.error("Trouble hitting zillow.com: %i", response.status_code)
        return None

    results = response.json()

    return results["map"]["properties"]


def get_zillow_results_from_web(max_articles=None):
    """
    Get a single page of results from Zillow's search and then slowly request their corresponding
    property detail pages to get images.
    
    Parameters
    ----------
    max_articles : int
        Once this threshold is crossed, stop requesting any further detail pages.
        
    Yields
    ------
    list
        Each set of images for a Zillow listing.
    """
    articles = get_page_of_zillow_articles(1, rect=PORTLAND)

    for counter, article in enumerate(articles):
        zp_id = article[0]
        price = article[3]

        article_results = []
        logger.debug("Getting images for %s.", zp_id)
        for image in get_images_from_detail_zillow_listing(zp_id):
            article_results.append(Result(zp_id, image, price))

        if len(article_results) == 0:
            logger.info("No images found for %s, recording an empty list.", zp_id)
            
        with open("./details/{zp_id}.json".format(zp_id=zp_id), "w") as f:
            f.write(
                json.dumps(
                    {"results": article_results},
                    indent=4,
                    sort_keys=True))

        yield article_results

        if max_articles and counter > max_articles:
            logger.info("Stopped downloading, hit max number of articles.")
            break

        # Add in a sleep timer if you actually use something like this, please never request too often.
        # sleep(0.5)


def download_image(result, image_dir):
    """
    Download a Zillow Result.
    
    Parameters
    ----------
    result : Result
        Result with an #image_url to download.
    image_dir : str
        Directory to store images, they are saved with their web filename.
    """
    response = requests.get(result.image_url, stream=True)

    logger.info("Downloading %s.", result)
    if response.status_code is 200:
        filename = result.image_url.split("/")[-1]
        with open(
                "{base}/{image_filename}".format(
                    base=image_dir,
                    image_filename=filename),
                "wb") as f:
            for chunk in response.iter_content():
                f.write(chunk)

# %%
for images in get_zillow_results_from_web(max_articles=10):
    for result in images:
        download_image(result, "./images")
# Out:
# DEBUG:Download Zillow Images:Getting images for 53849695.
# INFO:Download Zillow Images:No images found for 53849695, recording an empty list.
# DEBUG:Download Zillow Images:Getting images for 48523936.
# INFO:Download Zillow Images:No images found for 48523936, recording an empty list.
# DEBUG:Download Zillow Images:Getting images for 53889062.
# INFO:Download Zillow Images:Downloading Result(guid=53889062, image_url='http://photos1.zillowstatic.com/p_h/ISdc65uckebp2i1000000000.jpg', price=u'$370K').
# DEBUG:Download Zillow Images:Getting images for 53931228.
# INFO:Download Zillow Images:No images found for 53931228, recording an empty list.
# DEBUG:Download Zillow Images:Getting images for 53942176.
# INFO:Download Zillow Images:No images found for 53942176, recording an empty list.
# DEBUG:Download Zillow Images:Getting images for 53892567.
# INFO:Download Zillow Images:Downloading Result(guid=53892567, image_url='http://photos3.zillowstatic.com/p_h/IShbwzj3t5vvov0000000000.jpg', price=u'$210K').
# INFO:Download Zillow Images:Downloading Result(guid=53892567, image_url='http://photos1.zillowstatic.com/p_h/ISle5snzpkodtw0000000000.jpg', price=u'$210K').
# INFO:Download Zillow Images:Downloading Result(guid=53892567, image_url='http://photos1.zillowstatic.com/p_h/ISluhwb03t4unw0000000000.jpg', price=u'$210K').
# INFO:Download Zillow Images:Downloading Result(guid=53892567, image_url='http://photos2.zillowstatic.com/p_h/ISd83g5tlcggtw0000000000.jpg', price=u'$210K').
# INFO:Download Zillow Images:Downloading Result(guid=53892567, image_url='http://photos2.zillowstatic.com/p_h/ISdofkttykwwnw0000000000.jpg', price=u'$210K').
# INFO:Download Zillow Images:Downloading Result(guid=53892567, image_url='http://photos3.zillowstatic.com/p_h/IS5214nmh48jtw0000000000.jpg', price=u'$210K').
# INFO:Download Zillow Images:Downloading Result(guid=53892567, image_url='http://photos1.zillowstatic.com/p_h/ISxvyr4gdwzltw0000000000.jpg', price=u'$210K').
# INFO:Download Zillow Images:Downloading Result(guid=53892567, image_url='http://photos3.zillowstatic.com/p_h/IS5id8bnucoznw0000000000.jpg', price=u'$210K').
# INFO:Download Zillow Images:Downloading Result(guid=53892567, image_url='http://photos1.zillowstatic.com/p_h/ISxbbwsgq4g2ow0000000000.jpg', price=u'$210K').
# INFO:Download Zillow Images:Downloading Result(guid=53892567, image_url='http://photos2.zillowstatic.com/p_h/ISppwfm99orotw0000000000.jpg', price=u'$210K').
# INFO:Download Zillow Images:Downloading Result(guid=53892567, image_url='http://photos2.zillowstatic.com/p_h/ISp59kaamw75ow0000000000.jpg', price=u'$210K').
# INFO:Download Zillow Images:Downloading Result(guid=53892567, image_url='http://photos3.zillowstatic.com/p_h/IShz68s3ioz7ow0000000000.jpg', price=u'$210K').
# INFO:Download Zillow Images:Downloading Result(guid=53892567, image_url='http://photos1.zillowstatic.com/p_h/IS9t4w9xdgraow0000000000.jpg', price=u'$210K').
# DEBUG:Download Zillow Images:Getting images for 68350281.
# INFO:Download Zillow Images:No images found for 68350281, recording an empty list.
# DEBUG:Download Zillow Images:Getting images for 53846839.
# INFO:Download Zillow Images:Downloading Result(guid=53846839, image_url='http://photos3.zillowstatic.com/p_h/IS9pdoysdajopr1000000000.jpg', price=u'$120K').
# INFO:Download Zillow Images:Downloading Result(guid=53846839, image_url='http://photos2.zillowstatic.com/p_h/ISh7xtggy53xxr1000000000.jpg', price=u'$120K').
# INFO:Download Zillow Images:Downloading Result(guid=53846839, image_url='http://photos3.zillowstatic.com/p_h/IS91vhy9uxuzxr1000000000.jpg', price=u'$120K').
# INFO:Download Zillow Images:Downloading Result(guid=53846839, image_url='http://photos1.zillowstatic.com/p_h/IS1vs5g3qpm2yr1000000000.jpg', price=u'$120K').
# INFO:Download Zillow Images:Downloading Result(guid=53846839, image_url='http://photos2.zillowstatic.com/p_h/IStoqtxwlhe5yr1000000000.jpg', price=u'$120K').
# INFO:Download Zillow Images:Downloading Result(guid=53846839, image_url='http://photos3.zillowstatic.com/p_h/ISliohfqh968yr1000000000.jpg', price=u'$120K').
# INFO:Download Zillow Images:Downloading Result(guid=53846839, image_url='http://photos1.zillowstatic.com/p_h/ISdcm5xjd1yayr1000000000.jpg', price=u'$120K').
# INFO:Download Zillow Images:Downloading Result(guid=53846839, image_url='http://photos2.zillowstatic.com/p_h/IS56kted9tpdyr1000000000.jpg', price=u'$120K').
# INFO:Download Zillow Images:Downloading Result(guid=53846839, image_url='http://photos3.zillowstatic.com/p_h/ISxzhhw65lhgyr1000000000.jpg', price=u'$120K').
# INFO:Download Zillow Images:Downloading Result(guid=53846839, image_url='http://photos1.zillowstatic.com/p_h/ISptf5e01d9jyr1000000000.jpg', price=u'$120K').
# INFO:Download Zillow Images:Downloading Result(guid=53846839, image_url='http://photos2.zillowstatic.com/p_h/IShndtvtw41myr1000000000.jpg', price=u'$120K').
# INFO:Download Zillow Images:Downloading Result(guid=53846839, image_url='http://photos3.zillowstatic.com/p_h/IS9hbhdnswsoyr1000000000.jpg', price=u'$120K').
# DEBUG:Download Zillow Images:Getting images for 2100901769.
# INFO:Download Zillow Images:No images found for 2100901769, recording an empty list.
# DEBUG:Download Zillow Images:Getting images for 54001557.
# INFO:Download Zillow Images:No images found for 54001557, recording an empty list.
# DEBUG:Download Zillow Images:Getting images for 2103554030.
# INFO:Download Zillow Images:Downloading Result(guid=2103554030, image_url='http://photos1.zillowstatic.com/p_h/IS9dwmwg95a4jg1000000000.jpg', price=u'$620K').
# INFO:Download Zillow Images:Downloading Result(guid=2103554030, image_url='http://photos2.zillowstatic.com/p_h/IS17uaea5x17jg1000000000.jpg', price=u'$620K').
# INFO:Download Zillow Images:Downloading Result(guid=2103554030, image_url='http://photos3.zillowstatic.com/p_h/ISt0syv31pt9jg1000000000.jpg', price=u'$620K').
# INFO:Download Zillow Images:Downloading Result(guid=2103554030, image_url='http://photos1.zillowstatic.com/p_h/ISlupmdxwglcjg1000000000.jpg', price=u'$620K').
# INFO:Download Zillow Images:Downloading Result(guid=2103554030, image_url='http://photos2.zillowstatic.com/p_h/ISdonavqs8dfjg1000000000.jpg', price=u'$620K').
# INFO:Download Zillow Images:Downloading Result(guid=2103554030, image_url='http://photos3.zillowstatic.com/p_h/IS5ilycko05ijg1000000000.jpg', price=u'$620K').
# INFO:Download Zillow Images:Downloading Result(guid=2103554030, image_url='http://photos1.zillowstatic.com/p_h/ISxbjmudkswkjg1000000000.jpg', price=u'$620K').
# INFO:Download Zillow Images:Downloading Result(guid=2103554030, image_url='http://photos2.zillowstatic.com/p_h/ISp5hac7gkonjg1000000000.jpg', price=u'$620K').
# DEBUG:Download Zillow Images:Getting images for 82341016.
# INFO:Download Zillow Images:No images found for 82341016, recording an empty list.
